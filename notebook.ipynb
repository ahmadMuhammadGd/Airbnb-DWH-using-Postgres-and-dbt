# %%
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: sqlalchemy>=2.0 in ./dbt-env/lib/python3.10/site-packages (from ipython-sql) (2.0.35)
# Collecting prettytable
#   Downloading prettytable-3.11.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: ipython in ./dbt-env/lib/python3.10/site-packages (from ipython-sql) (8.12.3)
# Requirement already satisfied: sqlparse in ./dbt-env/lib/python3.10/site-packages (from ipython-sql) (0.5.1)
# Requirement already satisfied: six in ./dbt-env/lib/python3.10/site-packages (from ipython-sql) (1.16.0)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: greenlet!=0.4.17 in ./dbt-env/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./dbt-env/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: traitlets>=5 in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: jedi>=0.16 in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: backcall in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: pickleshare in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: decorator in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: matplotlib-inline in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (2.18.0)
# Requirement already satisfied: stack-data in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./dbt-env/lib/python3.10/site-packages (from ipython->ipython-sql) (3.0.48)
# Requirement already satisfied: wcwidth in ./dbt-env/lib/python3.10/site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./dbt-env/lib/python3.10/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./dbt-env/lib/python3.10/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: pure-eval in ./dbt-env/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in ./dbt-env/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./dbt-env/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Installing collected packages: ipython-genutils, prettytable, ipython-sql
# Successfully installed ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.11.0

# %%
# %load_ext sql

# %sql postgresql://ahmad:passw0rd@localhost:5432/bnb

# %%
from IPython.core.display import display, HTML

display(HTML("<style>.dataframe {width: 100%;}</style>"))
# Out:
# /tmp/ipykernel_118327/960771258.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.dataframe {width: 100%;}</style>

# %% [markdown]
# # Cheapest available listings during October 2024

# %%
# %%sql
#
# WITH ranked_listings AS (
#     SELECT
#         listing_id,
#         MIN(price) AS min_price,
#         MAX(price) AS max_price,
#         COUNT(available) AS availability_count,
#         RANK() OVER (
#             ORDER BY COUNT(available) DESC, MIN(price), MAX(price)
#         ) AS rank
#     FROM
#         dwh.fact_listing
#     WHERE
#         EXTRACT(MONTH FROM date) = 10
#         AND EXTRACT(YEAR FROM date) = 2024
#         AND available = True
#     GROUP BY
#         listing_id
# ),
# top_10_listings AS (
#     SELECT
#         listing_id,
#         CONCAT('$', min_price::TEXT) AS min_price,
#         CONCAT('$', max_price::TEXT) AS max_price,
#         availability_count
#     FROM
#         ranked_listings
#     WHERE rank <= 10
# )
# SELECT
#     *
# FROM
#     top_10_listings;
# Out:
#  * postgresql://ahmad:***@localhost:5432/bnb
# 14 rows affected.
# [(901850766927157553, '$15.00', '$15.00', 31),
#  (35118858, '$16.00', '$16.00', 31),
#  (568147116203638328, '$17.00', '$17.00', 31),
#  (1169548693691585795, '$18.00', '$18.00', 31),
#  (1057798613690701824, '$18.00', '$18.00', 31),
#  (1039618810131006061, '$18.00', '$18.00', 31),
#  (43612188, '$19.00', '$19.00', 31),
#  (1030300163371886351, '$19.00', '$19.00', 31),
#  (1065743258983020252, '$20.00', '$20.00', 31),
#  (35135494, '$20.00', '$20.00', 31),
#  (35135727, '$20.00', '$20.00', 31),
#  (664934285537366796, '$20.00', '$20.00', 31),
#  (37015541, '$20.00', '$20.00', 31),
#  (1070860009389942241, '$20.00', '$20.00', 31)]

# %% [markdown]
# # Most reviewed listing in October 2024

# %%
# %%sql
#
# WITH listing_review_cnt AS (
# 	SELECT
# 		listing_id
# 		, COUNT(listing_id) as review_cnt
# 	FROM
# 		dwh.fact_reviews
# 	WHERE
# 		EXTRACT(MONTH FROM DATE) = 10
# 	GROUP BY listing_id
# ),
# ranked_reviews_cnt AS (
# 	SELECT
# 		*
# 		, RANK() OVER(ORDER BY review_cnt DESC) as rnk
# 	FROM
# 		listing_review_cnt
# ),
# ranked_reviews_in_october AS (
# 	SELECT
# 		*
# 	FROM
# 		ranked_reviews_cnt
# )
# SELECT * FROM ranked_reviews_in_october LIMIT 10;
# Out:
#  * postgresql://ahmad:***@localhost:5432/bnb
# 10 rows affected.
# [(35118964, 269, 1),
#  (52981104, 221, 2),
#  (33764163, 131, 3),
#  (31977850, 101, 4),
#  (988917, 100, 5),
#  (5561974, 97, 6),
#  (18572961, 96, 7),
#  (36054333, 94, 8),
#  (24424717, 93, 9),
#  (30760852, 92, 10)]

# %% [markdown]
# # What is the most expensive neighbourhood in Barcelona ?

# %%
# %%sql
#
# WITH denormalized_listing AS (
#     SELECT
#         dl.listing_id,
#         dn.neighbourhood
#     FROM
#         dwh.dim_listing dl
#     LEFT JOIN
#         dwh.dim_neighbourhood dn
#     ON
#         dl.neighbourhood_id = dn.neighbourhood_id
# ),
# fact_listing_with_neighborhood AS (
#     SELECT
#         fl.price,
#         dl.neighbourhood
#     FROM
#         dwh.fact_listing fl
#     LEFT JOIN
#         denormalized_listing dl
#     ON
#         dl.listing_id = fl.listing_id
# ),
# final_price_by_neighborhood AS (
#     SELECT
#         ROUND(AVG(price), 2) AS avg_price,
#         neighbourhood,
#         RANK() OVER (ORDER BY AVG(price) DESC) AS rank
#     FROM
#         fact_listing_with_neighborhood
#     GROUP BY
#         neighbourhood
# )
# SELECT
#       CONCAT('$', avg_price::TEXT) AS avg_price
#     , neighbourhood
# FROM
#     final_price_by_neighborhood
# ORDER BY
#     rank
# LIMIT 10;
# Out:
#  * postgresql://ahmad:***@localhost:5432/bnb
# 10 rows affected.
# [('$500.75', "la Dreta de l'Eixample"),
#  ('$452.60', 'la Sagrera'),
#  ('$415.31', 'el Poblenou'),
#  ('$359.16', 'el Fort Pienc'),
#  ('$321.81', 'Sant Antoni'),
#  ('$319.84', 'Diagonal Mar i el Front Marítim del Poblenou'),
#  ('$301.36', 'les Tres Torres'),
#  ('$299.52', 'la Vila Olímpica del Poblenou'),
#  ('$293.67', 'el Parc i la Llacuna del Poblenou'),
#  ('$291.78', 'la Font de la Guatlla')]

# %% [markdown]
# # Recommendition for a man with his wife and 2 children looking for a week vacation around November 2024

# %%
# %%sql
#
#
# WITH filtered_listing AS (
# 	SELECT
# 		listing_id
# 		, bathrooms
# 		, bedrooms
# 		, beds
# 		, neighbourhood_id
# 	FROM
# 		dwh.dim_listing
# 	WHERE
# 		bathrooms = 1
# 		AND
# 		bedrooms = 2 OR bedrooms = 2
# 		AND
# 		beds = 2 OR beds = 3
# )
# ,
# transform_query AS(
#     SELECT
#         fc.listing_id
# 		, CAST(bathrooms AS INTEGER)
# 		, bedrooms
# 		, beds
# 		, dn.neighbourhood_group
# 		, dn.neighbourhood
#         , fc.price
#         , fc.date
# 		, dd.week_start_date
# 		, dd.week_end_date
#     FROM
#         dwh.fact_listing fc
#     LEFT JOIN
#         filtered_listing fl
#     ON
#         fl.listing_id = fc.listing_id
# 	LEFT JOIN
# 		dwh.dim_date dd
# 	ON
# 		fc.date = dd.date_day
# 	LEFT JOIN
# 		dwh.dim_neighbourhood dn
# 	ON
# 		fl.neighbourhood_id = dn.neighbourhood_id
#     WHERE
#         fl.listing_id IS NOT NULL
#         AND dd.month_of_year = 11
#         AND dd.year_number = 2024
# )
# ,
# final_result AS (
#     SELECT
# 		DISTINCT
#         listing_id
# 		, bathrooms
# 		, bedrooms
# 		, beds
# 		, neighbourhood_group
# 		, neighbourhood
#         , ROUND(AVG(price), 2) AS avg_price_per_day
#         , week_start_date
#         , week_end_date
#     FROM transform_query
#     GROUP BY
# 	      listing_id
# 		, bathrooms
# 		, bedrooms
# 		, beds
# 		, neighbourhood_group
# 		, neighbourhood
#         , week_start_date
#         , week_end_date
# 	ORDER BY ROUND(AVG(price), 2)
# )
# SELECT
# 	listing_id
# 	, CONCAT('$', avg_price_per_day::TEXT) AS avg_price_per_day
# 	, bathrooms
# 	, bedrooms
# 	, beds
# 	, neighbourhood_group
# 	, neighbourhood
# 	, week_start_date
# 	, week_end_date
# FROM
# 	final_result
# LIMIT 20
# Out:
#  * postgresql://ahmad:***@localhost:5432/bnb
# 20 rows affected.
# [(898276757093957812, '$10.00', 2, 2, 2, 'Eixample', "l'Antiga Esquerra de l'Eixample", datetime.date(2024, 10, 27), datetime.date(2024, 11, 2)),
#  (898276757093957812, '$10.00', 2, 2, 2, 'Eixample', "l'Antiga Esquerra de l'Eixample", datetime.date(2024, 11, 3), datetime.date(2024, 11, 9)),
#  (898276757093957812, '$10.00', 2, 2, 2, 'Eixample', "l'Antiga Esquerra de l'Eixample", datetime.date(2024, 11, 10), datetime.date(2024, 11, 16)),
#  (898276757093957812, '$10.00', 2, 2, 2, 'Eixample', "l'Antiga Esquerra de l'Eixample", datetime.date(2024, 11, 17), datetime.date(2024, 11, 23)),
#  (898276757093957812, '$10.00', 2, 2, 2, 'Eixample', "l'Antiga Esquerra de l'Eixample", datetime.date(2024, 11, 24), datetime.date(2024, 11, 30)),
#  (1227221841045363530, '$10.00', 1, 1, 3, 'Ciutat Vella', 'el Raval', datetime.date(2024, 10, 27), datetime.date(2024, 11, 2)),
#  (1227221841045363530, '$10.00', 1, 1, 3, 'Ciutat Vella', 'el Raval', datetime.date(2024, 11, 3), datetime.date(2024, 11, 9)),
#  (1227221841045363530, '$10.00', 1, 1, 3, 'Ciutat Vella', 'el Raval', datetime.date(2024, 11, 10), datetime.date(2024, 11, 16)),
#  (1227221841045363530, '$10.00', 1, 1, 3, 'Ciutat Vella', 'el Raval', datetime.date(2024, 11, 17), datetime.date(2024, 11, 23)),
#  (1227221841045363530, '$10.00', 1, 1, 3, 'Ciutat Vella', 'el Raval', datetime.date(2024, 11, 24), datetime.date(2024, 11, 30)),
#  (1141216526957322551, '$14.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 10, 27), datetime.date(2024, 11, 2)),
#  (1141216526957322551, '$14.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 3), datetime.date(2024, 11, 9)),
#  (1141216526957322551, '$14.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 10), datetime.date(2024, 11, 16)),
#  (1141216526957322551, '$14.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 17), datetime.date(2024, 11, 23)),
#  (1141216526957322551, '$14.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 24), datetime.date(2024, 11, 30)),
#  (1141940426102796693, '$16.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 10, 27), datetime.date(2024, 11, 2)),
#  (1141940426102796693, '$16.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 3), datetime.date(2024, 11, 9)),
#  (1141940426102796693, '$16.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 10), datetime.date(2024, 11, 16)),
#  (1141940426102796693, '$16.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 17), datetime.date(2024, 11, 23)),
#  (1141940426102796693, '$16.00', 1, 3, 3, 'Horta-Guinardó', 'el Guinardó', datetime.date(2024, 11, 24), datetime.date(2024, 11, 30))]
